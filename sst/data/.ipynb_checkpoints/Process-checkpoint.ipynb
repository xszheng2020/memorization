# %%
# !wget https://nlp.stanford.edu/sentiment/trainDevTestTrees_PTB.zip
# !unzip trainDevTestTrees_PTB.zip

# %%
import nltk
a = nltk.corpus.BracketParseCorpusReader("trees", "(train|dev|test)\.txt")

text = {}
labels = {}
keys = ['train', 'dev', 'test']
for k in keys :
    text[k] = [x.leaves() for x in a.parsed_sents(k+'.txt') if x.label() != '2']
    labels[k] = [int(x.label()) for x in a.parsed_sents(k+'.txt') if x.label() != '2']
    print(len(text[k]))
    
import spacy
nlp = spacy.load('en', disable=['parser', 'tagger', 'ner'])
import re

def tokenize(text) :
    text = " ".join(text)
    text = text.replace("-LRB-", '')
    text = text.replace("-RRB-", " ")
    text = re.sub(r'\W', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    text = text.strip()
    tokens = " ".join([t.text.lower() for t in nlp(text)])
    return tokens

for k in keys :
    text[k] = [tokenize(t) for t in text[k]]
    labels[k] = [1 if x >= 3 else 0 for x in labels[k]]
# Out:
# 6920
# 872
# 1821

# %%
import pandas as pd
pd.set_option('max_colwidth', 256)

df_texts = []
df_labels = []
df_exp_split = []

for k in keys :
    df_texts += text[k]
    df_labels += labels[k]
    df_exp_split += [k]*len(text[k])
    
data = pd.DataFrame({'text' : df_texts, 'label' : df_labels, 'exp_split' : df_exp_split})

# %%
data.head(32)
# Out:
#                                                                                                                                                                                                                                                   text  \
# 0                                                                            the rock is destined to be the 21st century s new conan and that he s going to make a splash even greater than arnold schwarzenegger jean claud van damme or steven segal
# 1                              the gorgeously elaborate continuation of the lord of the rings trilogy is so huge that a column of words can not adequately describe co writer director peter jackson s expanded vision of j r r tolkien s middle earth
# 2                                                   singer composer bryan adams contributes a slew of songs a few potential hits a few more simply intrusive to the story but the whole package certainly captures the intended er spirit of the piece
# 3                                                                                                                                                                                                                   yet the act is still charming here
# 4                                                                                                     whether or not you re enlightened by any of derrida s lectures on the other and the self derrida is an undeniably fascinating and playful fellow
# 5                                                                                                                     just the labour involved in creating the layered richness of the imagery in this chiaroscuro of madness and light is astonishing
# 6                                                                                                                                                             part of the charm of satin rouge is that it avoids the obvious with humour and lightness
# 7                                                                                                                                                                                               a screenplay more ingeniously constructed than memento
# 8                                                                                                                                                                                                                     extreme ops exceeds expectations
# 9                                                                                                                                                                         good fun good action good acting good dialogue good pace good cinematography
# 10                                                                                                                                                                                                                      dramas like this make it human
# 11                                                                                                                                                                                  still this flick is fun and host to some truly excellent sequences
# 12                                                                          australian actor director john polson and award winning english cinematographer giles nuttgens make a terrific effort at disguising the obvious with energy and innovation
# 13                                                                                                                     you walk out of the good girl with mixed emotions disapproval of justine combined with a tinge of understanding for her actions
# 14                                                                                                                                                                                                           absorbing character study by andré turpin
# 15                                                                                                                                                                                    if you love reading and or poetry then by all means check it out
# 16                                                                                                                                                                                                                             you ll probably love it
# 17                                                                                                                                                                                       frailty has been written so well that even a simple goddammit
# 18                                                                                                                               grenier is terrific bringing an unforced rapid fire delivery to toback s heidegger and nietzsche referencing dialogue
# 19                                                                                                                                                                                                                            the actors are fantastic
# 20                                                                                                                                                                                                they are what makes it worth the trip to the theatre
# 21                                                                                                                  taymor utilizes the idea of making kahlo s art a living breathing part of the movie often catapulting the artist into her own work
# 22                                                                                                                                                                                                                              this is n t a new idea
# 23                                                                                                                                                                                  it s been done before but never so vividly or with so much passion
# 24                                                                    take care of my cat is an honestly nice little film that takes us on an examination of young adult life in urban south korea through the hearts and minds of the five principals
# 25                                                                                                                                                                                           what empire lacks in depth it makes up for with its heart
# 26                                                                                                                                                                               light silly photographed with colour and depth and rather a good time
# 27                                                                  but tongue in cheek preposterousness has always been part of for the most part wilde s droll whimsy helps being earnest overcome its weaknesses and parker s creative interference
# 28                                                                                                                                                                          much of the movie s charm lies in the utter cuteness of stuart and margolo
# 29                                                                                                                                                                                                   their computer animated faces are very expressive
# 30  spiced with humor i speak fluent flatula advises denlopp after a rather er bubbly exchange with an alien deckhand and witty updatings silver s parrot has been replaced with morph a cute alien creature who mimics everyone and everything around
# 31                                                                                                                                                                                                              there s an energy to y tu mamá también
#
#     label exp_split
# 0       1     train
# 1       1     train
# 2       1     train
# 3       1     train
# 4       1     train
# 5       1     train
# 6       1     train
# 7       1     train
# 8       1     train
# 9       1     train
# 10      1     train
# 11      1     train
# 12      1     train
# 13      1     train
# 14      1     train
# 15      1     train
# 16      1     train
# 17      1     train
# 18      1     train
# 19      1     train
# 20      1     train
# 21      1     train
# 22      0     train
# 23      1     train
# 24      1     train
# 25      1     train
# 26      1     train
# 27      1     train
# 28      1     train
# 29      1     train
# 30      1     train
# 31      1     train

# %%
import json
from tqdm import tqdm

import os
os.makedirs('data/', exist_ok=True)
for key in ['train', 'dev', 'test'] :
    data_key = data[data.exp_split == key].to_dict(orient='records')
    data_key = [{'document' : x['text'], 'label' : x['label']} for x in tqdm(data_key)]
    f = open('data/' + key + '.jsonl', 'w')
    f.write('\n'.join([json.dumps(line) for line in data_key]))
    f.close()
# Out:
# 100%|██████████| 6920/6920 [00:00<00:00, 985621.56it/s]
# 100%|██████████| 872/872 [00:00<00:00, 903739.33it/s]
# 100%|██████████| 1821/1821 [00:00<00:00, 1050306.32it/s]

# %%
import json
for key in ['train', 'dev', 'test'] :
    data_key = [json.loads(line) for line in open('data/' + key + '.jsonl')]
    for i, d in enumerate(data_key) :
        d['idx'] = key + '_' + str(i)
    f = open('data/' + key + '.jsonl', 'w')
    f.write('\n'.join([json.dumps(line) for line in data_key]))
    f.close()
